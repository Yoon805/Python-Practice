# %%
import pandas as pd

# %%
targetUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002477494&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR_20200501"

# %%
indata = pd.read_csv(targetUrl, encoding="ms949")
indata.tail()
# Out:
#        연도  월  전국(PIR)  서울(PIR)  부산(PIR)  대구(PIR)  인천(PIR)  광주(PIR)  대전(PIR)  \
# 190  2020  1     4.47     5.44     4.84     5.16     4.39     4.76     4.52
# 191  2020  2     4.45     5.02     5.04     4.92     4.49     4.52     4.36
# 192  2020  3     4.76     5.12     5.22     5.20     4.76     5.04     4.74
# 193  2020  4     4.83     4.95     5.67     5.91     4.78     5.41     5.40
# 194  2020  5     4.56     4.88     7.01     5.44     4.56     3.16     4.72
#
#      울산(PIR)  ...  세종(LIR)  경기(LIR)  강원(LIR)  충북(LIR)  충남(LIR)  전북(LIR)  \
# 190     4.11  ...     2.63     2.39     1.90     1.76     1.87     1.94
# 191     3.90  ...     2.69     2.34     1.96     1.87     1.89     1.83
# 192     4.11  ...     2.22     2.56     2.13     1.98     2.03     1.97
# 193     4.44  ...     1.73     2.54     2.13     2.09     2.14     2.11
# 194     5.77  ...     0.00     2.23     2.44     1.08     1.65     1.04
#
#      전남(LIR)  경북(LIR)  경남(LIR)  제주(LIR)
# ...

# %%
import pandas as pd

targetUrl2 = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002336443&fileDetailSn=1&dataNm=%ED%86%B5%EA%B3%84%EC%B2%AD_%EB%82%98%EB%9D%BC%ED%86%B5%EA%B3%84_%EC%9A%B0%ED%8E%B8%EB%B2%88%ED%98%B8_20211110"

indata2 = pd.read_csv(targetUrl2, encoding = "ms949")

indata2.tail()
# Out:
#          우편번호  우편번호순서   도이름 시군구이름 읍면동이름 리건물이름   동호              전체주소
# 52538  799821      31  경상북도   울릉군    북면    나리  NaN    경상북도 울릉군 북면 나리
# 52539  799822      21  경상북도   울릉군    북면  천부4리  NaN  경상북도 울릉군 북면 천부4리
# 52540  799822      11  경상북도   울릉군    북면  천부3리  NaN  경상북도 울릉군 북면 천부3리
# 52541  799822       1  경상북도   울릉군    북면  나리2리  NaN  경상북도 울릉군 북면 나리2리
# 52542  799823       1  경상북도   울릉군    북면   현포리  NaN   경상북도 울릉군 북면 현포리

# %% [markdown]
# ### 4. json 데이터 불러오기

# %%
targetUrl3 = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=MzIxMjRhMjUyYmQxOTA4Y2E5OTQ5NmE1NzJlMGQxMDU=&format=json&jsonVD=Y&userStatsId=yoond395/101/DT_1B040A3/2/1/20220405102902&prdSe=M&newEstPrdCnt=1"

# %%
pd.read_json(targetUrl3)
# Out:
#                TBL_NM  PRD_DE      TBL_ID ITM_NM       ITM_NM_ENG ITM_ID  \
# 0   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 1   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 2   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 3   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 4   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 5   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 6   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 7   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 8   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 9   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 10  행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# 11  행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수  Koreans (Total)    T20
# ...

# %% [markdown]
# ### 5. xml 형태의 데이터

# %%
import requests
from lxml import html
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?"
queryParams = "LAWD_CD=11110&DEAL_YMD=201512&serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D"

# %%
response = requests.get(url+queryParams)
response.encoding = 'utf-8'

# %%
### parser가 아니라 lxml-xml 으로 변환
xmlobj = BeautifulSoup(response.text,"lxml-xml")
itemTag = xmlobj.find(name = "items")

# %%
itemsTag = itemTag.findAll(name = "item")

# %%
eachTag = itemsTag[0]
eachTag
# Out:
# <item><거래금액>    82,500</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><법정동> 사직동</법정동><아파트>광화문스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><중개사소재지> </중개사소재지><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>

# %%
columns = eachTag.findAll()

# %%
columns[0]
# Out:
# <거래금액>    82,500</거래금액>

# %%
columns[0].name
# Out:
# '거래금액'

# %%
columns[0].text
# Out:
# '    82,500'

# %%
lawCodeUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002494239&fileDetailSn=1&dataNm=%EA%B5%AD%ED%86%A0%EA%B5%90%ED%86%B5%EB%B6%80_%EC%A0%84%EA%B5%AD%20%EB%B2%95%EC%A0%95%EB%8F%99_20211217"

lawCodeData =pd.read_csv(lawCodeUrl, encoding="ms949")

lawCodeList = lawCodeData.법정동코드.tolist()

# %%
yearList =["202201","202202","202203"]

# %%
### 교수님 코드

import requests
from lxml import html
from bs4 import BeautifulSoup 
import pandas as pd
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote

baseUrl = "http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade"
inApiKey="AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D"
inYmd = "201512"
inLawCode = "11110"

queryParams = '?' + urlencode(
    {
        quote_plus('ServiceKey') : inApiKey,
        quote_plus('LAWD_CD'): inLawCode,
        quote_plus('DEAL_YMD'): inYmd
     }
)
